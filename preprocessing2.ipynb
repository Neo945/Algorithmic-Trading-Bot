# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./dataset.csv')

# %%
print(data)
# Out:
#                  datetime         symbol     open     high      low    close  \
# 0     2021-07-23 09:45:00  NSE:TATASTEEL  1282.60  1283.50  1278.05  1279.05
# 1     2021-07-26 03:45:00  NSE:TATASTEEL  1289.80  1292.80  1278.05  1283.25
# 2     2021-07-26 04:45:00  NSE:TATASTEEL  1283.25  1289.45  1283.15  1288.00
# 3     2021-07-26 05:45:00  NSE:TATASTEEL  1288.00  1289.00  1283.40  1287.35
# 4     2021-07-26 06:45:00  NSE:TATASTEEL  1287.30  1308.25  1286.50  1302.95
# ...                   ...            ...      ...      ...      ...      ...
# 2995  2022-02-17 08:45:00  NSE:EICHERMOT  2706.00  2733.00  2700.10  2719.10
# 2996  2022-02-17 09:45:00  NSE:EICHERMOT  2719.30  2727.50  2714.85  2714.85
# 2997  2022-02-18 03:45:00  NSE:EICHERMOT  2703.45  2735.00  2697.15  2727.70
# 2998  2022-02-18 04:45:00  NSE:EICHERMOT  2727.45  2729.00  2718.40  2725.00
# 2999  2022-02-18 05:45:00  NSE:EICHERMOT  2725.00  2729.00  2721.60  2727.75
#
#          volume
# 0           NaN
# ...

# %%
data = data.sample(frac=1)

# %%
head = data.head()
head.iloc[:,2].values
head['open']
# Out:
# 2059    2735.50
# 473     1360.75
# 443     1323.40
# 38      1421.45
# 943     1179.50
# Name: open, dtype: float64

# %%
plt.hist(x=data['open'], bins=1000, density=1, alpha=0.7, color='blue')
# Out:
# (array([3.99175418e-04, 3.99175418e-04, 1.46364320e-03, 9.31409308e-04,
#         7.79342482e-04, 1.59670167e-03, 8.55375895e-04, 1.14050119e-03,
#         7.79342482e-04, 2.47108592e-04, 3.61158711e-04, 5.13225537e-04,
#         7.98350835e-04, 1.50165990e-03, 1.15950955e-03, 6.27275656e-04,
#         3.23142005e-04, 5.89258950e-04, 5.89258950e-04, 1.00744272e-03,
#         1.14050119e-03, 1.10248449e-03, 2.85125298e-04, 7.60334129e-05,
#         1.71075179e-04, 1.14050119e-04, 5.70250597e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
plt.hist(x=data['open'], bins=100, density=1, alpha=0.7, color='blue')
# Out:
# (array([8.59177566e-04, 7.47028282e-04, 2.94629475e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.72976014e-04,
#         7.48929117e-04, 6.91904057e-04, 2.87026134e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
plt.boxplot(data.head(100)['open'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11314ace080>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11314ace6e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11314acddb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x11314acebc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11314acee90>],
#  'means': []}

# %%
sns.lineplot(x='open', y='close', data=data.head(1000))
# Out:
# <AxesSubplot:xlabel='open', ylabel='close'>

# %%
sns.lineplot(x='open', y='close', data=data.head(100))
# Out:
# <AxesSubplot:xlabel='open', ylabel='close'>

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(x = "total_bill", y = "tip", data = tips_df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x  = "size", y = "total_bill", data = tips_df, hue ="sex")
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.lineplot(x = "size", y = "total_bill", data = tips_df, hue ="sex", style = "sex", palette ="hot", dashes = True, markers = ["o", "<"], legend = "brief",)
plt.title("Line Plot", fontsize = 20)
plt.xlabel("Size", fontsize = 15)
plt.ylabel("Total Bill", fontsize = 15)
plt.show()

# %%
data.corr()
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999997  0.999994  0.999991  0.995615
# high    0.999997  1.000000  0.999993  0.999995  0.995599
# low     0.999994  0.999993  1.000000  0.999996  0.995635
# close   0.999991  0.999995  0.999996  1.000000  0.995619
# volume  0.995615  0.995599  0.995635  0.995619  0.000000

# %%
sns.heatmap(data.head(10).corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x="open", y ="close", data =data.head(100), kind="reg")

# %%
sns.countplot(data['symbol'])
# Out:
# f:\tradingAlgorithms\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='symbol', ylabel='count'>

# %%
sns.countplot(y=data['symbol'])
sns.pairplot(data.head(100))
sns.pairplot(data, hue="symbol")
sns.displot(data['open'])

# %%
sns.countplot(x="symbol", data=data)
# Out:
# <AxesSubplot:xlabel='symbol', ylabel='count'>

# %%
sns.displot(data.head(100)['open'], bins = 30, color = "red")

# %%
sns.boxplot(data.head(100)['open'])
# Out:
# f:\tradingAlgorithms\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='open'>

# %%
sns.boxplot(x="open", y="close", hue="datetime", data=data.head(10))
# Out:
# <AxesSubplot:xlabel='open', ylabel='close'>

# %%
sns.barplot(x="open", y="datetime", data=data.head(10))
# Out:
# <AxesSubplot:xlabel='open', ylabel='datetime'>

# %%
sns.barplot(y="open", x="datetime", data=data.head(20))
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='open'>
